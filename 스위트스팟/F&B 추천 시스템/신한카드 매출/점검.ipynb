# %%
import pandas as pd 


data = pd.read_csv("./month_fill.csv", encoding='utf-8')

# %%
data
# Out:
#           TA_YM MCT_RY_NM        MCTNM BRD_NM      ARED BZNCD     LALXCVL  \
# 0        202301        한식   "미 "갈매기살전문    NaN  20031105   익선동  126.991069
# 1        202302        한식   "미 "갈매기살전문    NaN  20031105   익선동  126.991069
# 2        202303        한식   "미 "갈매기살전문    NaN  20031105   익선동  126.991069
# 3        202304        한식   "미 "갈매기살전문    NaN  20031105   익선동  126.991069
# 4        202305        한식   "미 "갈매기살전문    NaN  20031105   익선동  126.991069
# ...         ...       ...          ...    ...       ...   ...         ...
# 1410719  202308        양식     （주）에스알인베    NaN  20100121   수서역  127.103227
# 1410720  202309        양식     （주）에스알인베    NaN  20100121   수서역  127.103227
# 1410721  202310        양식     （주）에스알인베    NaN  20100121   수서역  127.103227
# 1410722  202311        양식     （주）에스알인베    NaN  20100121   수서역  127.103227
# 1410723  202312        양식     （주）에스알인베    NaN  20100121   수서역  127.103227
#
#            LALYCVL  EST_AMT_TOT  EST_CNT_TOT  ...  소득5천만이하  소득7천만이하  소득1억이하  \
# ...

# %%
# 매출데이터가 빈값이 있는지 확인하자.

data.columns
# Out:
# Index(['TA_YM', 'MCT_RY_NM', 'MCTNM', 'BRD_NM', 'ARED', 'BZNCD', 'LALXCVL',
#        'LALYCVL', 'EST_AMT_TOT', 'EST_CNT_TOT', 'WKND_RT', '시간_0813',
#        '시간_1417', '시간_1821', '시간_2207', '남성_20대', '남성_30대', '남성_40대', '남성_50대',
#        '남성_60대', '여성_20대', '여성_30대', '여성_40대', '여성_50대', '여성_60대', '소득정보없음',
#        '소득3천만이하', '소득5천만이하', '소득7천만이하', '소득1억이하', '소득1억초과', '생애단계_싱글',
#        '생애단계_영유아', '생애단계_청소년', 'MCT_BSE_AR', 'MCT_RY_NM2', 'OUB_RY_MI_CZ_NM'],
#       dtype='object')

# %%
data['EST_AMT_TOT'].isnull().value_counts() # 빈값은 없음.
# Out:
# EST_AMT_TOT
# False    1410724
# Name: count, dtype: int64

# %%
# 30개 무작위 추출하여 확인하자! 

data[data['MCTNM'] == '(주)경성키친']
# Out:
#        TA_YM MCT_RY_NM    MCTNM BRD_NM      ARED BZNCD     LALXCVL    LALYCVL  \
# 5335  202303      식품잡화  (주)경성키친    NaN  20200728   NaN  127.027739  37.568476
# 5336  202304      식품잡화  (주)경성키친    NaN  20200728   NaN  127.027739  37.568476
# 5337  202305      식품잡화  (주)경성키친    NaN  20200728   NaN  127.027739  37.568476
# 5338  202306      식품잡화  (주)경성키친    NaN  20200728   NaN  127.027739  37.568476
# 5339  202307      식품잡화  (주)경성키친    NaN  20200728   NaN  127.027739  37.568476
# 5340  202308      식품잡화  (주)경성키친    NaN  20200728   NaN  127.027739  37.568476
# 5341  202309      식품잡화  (주)경성키친    NaN  20200728   NaN  127.027739  37.568476
# 5342  202310      식품잡화  (주)경성키친    NaN  20200728   NaN  127.027739  37.568476
# 5343  202311      식품잡화  (주)경성키친    NaN  20200728   NaN  127.027739  37.568476
# 5344  202312      식품잡화  (주)경성키친    NaN  20200728   NaN  127.027739  37.568476
#
#       EST_AMT_TOT  EST_CNT_TOT  ...  소득5천만이하  소득7천만이하  소득1억이하  소득1억초과  \
# ...
