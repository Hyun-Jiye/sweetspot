# %%
import requests
import pprint 
import json 
import pandas as pd 
from urllib.request import Request , urlopen
import urllib.request
from urllib.parse import urlencode, quote_plus
import math
import os

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
code = [11200650,11200660,11200670,11200690]

# %%
path = "./행정동단위 데이터/"

# %%
# 수동으로 append 했던 방식 없애고 
# data1 = pd.read_csv("./행정동단위 데이터/LOCAL_PEOPLE_DONG_202301.csv")
# data2 = pd.read_csv("./행정동단위 데이터/LOCAL_PEOPLE_DONG_202302.csv")
# data3 = pd.read_csv("./행정동단위 데이터/LOCAL_PEOPLE_DONG_202303.csv")
# data4 = pd.read_csv("./행정동단위 데이터/LOCAL_PEOPLE_DONG_202304.csv")
# data5 = pd.read_csv("./행정동단위 데이터/LOCAL_PEOPLE_DONG_202305.csv")
# data6 = pd.read_csv("./행정동단위 데이터/LOCAL_PEOPLE_DONG_202306.csv")
# data7 = pd.read_csv("./행정동단위 데이터/LOCAL_PEOPLE_DONG_202307.csv")
# data8 = pd.read_csv("./행정동단위 데이터/LOCAL_PEOPLE_DONG_202308.csv")
# data9 = pd.read_csv("./행정동단위 데이터/LOCAL_PEOPLE_DONG_202309.csv")
# data10 = pd.read_csv("./행정동단위 데이터/LOCAL_PEOPLE_DONG_202310.csv")
# data11 = pd.read_csv("./행정동단위 데이터/LOCAL_PEOPLE_DONG_202311.csv")
# data12 = pd.read_csv("./행정동단위 데이터/LOCAL_PEOPLE_DONG_202312.csv")

# %%
path = './행정동단위 데이터/'

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.0.3

# %%
# 여러 file 합쳐서 Dataframe 형성 
file_list = os.listdir(path)
print(file_list)
file_list_csv = [file for file in file_list if file.endswith('csv')]
print(file_list_csv)
df_total = pd.DataFrame() 

for file in file_list_csv:
    df= pd.read_csv(path+file, dtype = 'object')
        
    df_total = pd.concat([df_total,df],axis = 0 , ignore_index=True)

print(df_total.head()) # Columns 만 확인
# Out:
# ['.DS_Store', 'LOCAL_PEOPLE_DONG_202308.csv', 'LOCAL_PEOPLE_DONG_202309.csv', 'LOCAL_PEOPLE_DONG_202302.csv', 'LOCAL_PEOPLE_DONG_202303.csv', 'LOCAL_PEOPLE_DONG_202301.csv', 'LOCAL_PEOPLE_DONG_202304.csv', 'LOCAL_PEOPLE_DONG_202310.csv', 'LOCAL_PEOPLE_DONG_202311.csv', 'LOCAL_PEOPLE_DONG_202305.csv', 'LOCAL_PEOPLE_DONG_202307.csv', 'LOCAL_PEOPLE_DONG_202306.csv', 'LOCAL_PEOPLE_DONG_202312.csv']
# ['LOCAL_PEOPLE_DONG_202308.csv', 'LOCAL_PEOPLE_DONG_202309.csv', 'LOCAL_PEOPLE_DONG_202302.csv', 'LOCAL_PEOPLE_DONG_202303.csv', 'LOCAL_PEOPLE_DONG_202301.csv', 'LOCAL_PEOPLE_DONG_202304.csv', 'LOCAL_PEOPLE_DONG_202310.csv', 'LOCAL_PEOPLE_DONG_202311.csv', 'LOCAL_PEOPLE_DONG_202305.csv', 'LOCAL_PEOPLE_DONG_202307.csv', 'LOCAL_PEOPLE_DONG_202306.csv', 'LOCAL_PEOPLE_DONG_202312.csv']
#   기준일ID     시간대구분               행정동코드     총생활인구수       남자0세부터9세생활인구수  \
# 0    00  11110560  18298.601699999999   542.7872            392.6157
# ...

# %%
#column확인 
df_total.columns
# Out:
# Index(['기준일ID', '시간대구분', '행정동코드', '총생활인구수', '남자0세부터9세생활인구수', '남자10세부터14세생활인구수',
#        '남자15세부터19세생활인구수', '남자20세부터24세생활인구수', '남자25세부터29세생활인구수',
#        '남자30세부터34세생활인구수', '남자35세부터39세생활인구수', '남자40세부터44세생활인구수',
#        '남자45세부터49세생활인구수', '남자50세부터54세생활인구수', '남자55세부터59세생활인구수',
#        '남자60세부터64세생활인구수', '남자65세부터69세생활인구수', '남자70세이상생활인구수', '여자0세부터9세생활인구수',
#        '여자10세부터14세생활인구수', '여자15세부터19세생활인구수', '여자20세부터24세생활인구수',
#        '여자25세부터29세생활인구수', '여자30세부터34세생활인구수', '여자35세부터39세생활인구수',
#        '여자40세부터44세생활인구수', '여자45세부터49세생활인구수', '여자50세부터54세생활인구수',
#        '여자55세부터59세생활인구수', '여자60세부터64세생활인구수', '여자65세부터69세생활인구수',
#        '여자70세이상생활인구수'],
#       dtype='object')

# %%
df_total.reset_index()
# Out:
#            index 기준일ID     시간대구분               행정동코드     총생활인구수  \
# 0              0    00  11110560  18298.601699999999   542.7872
# 1              1    00  11140625          13906.9668   373.7146
# 2              2    00  11710631  32190.094300000001  1329.3009
# 3              3    00  11680630  30591.927500000002   702.7857
# 4              4    00  11440720          22091.3105   520.8461
# ...          ...   ...       ...                 ...        ...
# 3714235  3714235    23  11110560  18530.063300000002   539.9718
# 3714236  3714236    23  11110670  6238.8665000000001    53.9233
# 3714237  3714237    23  11740690  5271.8468999999996   229.7714
# 3714238  3714238    23  11560720          25025.5448   311.2179
# 3714239  3714239    23  11680580  21396.355500000001   762.1061
#
#               남자0세부터9세생활인구수     남자10세부터14세생활인구수     남자15세부터19세생활인구수  \
# 0                  392.6157  506.81360000000001  595.33969999999999
# ...

# %%
df_total.rename(columns = {'index':'기준일ID','기준일ID' :'시간대구분', '시간대구분':'행정동코드', '행정동코드':'총생활인구수','총생활인구수': '남자0세부터9세생활인구수',
       '남자0세부터9세생활인구수' : '남자10세부터14세생활인구수', '남자10세부터14세생활인구수': '남자15세부터19세생활인구수', '남자15세부터19세생활인구수':'남자20세부터24세생활인구수',
       '남자20세부터24세생활인구수':'남자25세부터29세생활인구수', '남자25세부터29세생활인구수':'남자30세부터34세생활인구수', '남자30세부터34세생활인구수':'남자35세부터39세생활인구수',
       '남자35세부터39세생활인구수':'남자40세부터44세생활인구수', '남자40세부터44세생활인구수':'남자45세부터49세생활인구수','남자45세부터49세생활인구수': '남자50세부터54세생활인구수',
       '남자50세부터54세생활인구수':'남자55세부터59세생활인구수','남자55세부터59세생활인구수': '남자60세부터64세생활인구수', '남자60세부터64세생활인구수':'남자65세부터69세생활인구수', '남자65세부터69세생활인구수':'남자70세이상생활인구수',
       '남자70세이상생활인구수':'여자0세부터9세생활인구수', '여자0세부터9세생활인구수':'여자10세부터14세생활인구수', '여자10세부터14세생활인구수':'여자15세부터19세생활인구수',
       '여자15세부터19세생활인구수':'여자20세부터24세생활인구수', '여자20세부터24세생활인구수':'여자25세부터29세생활인구수', '여자25세부터29세생활인구수':'여자30세부터34세생활인구수',
       '여자30세부터34세생활인구수':'여자35세부터39세생활인구수', '여자35세부터39세생활인구수':'여자40세부터44세생활인구수', '여자40세부터44세생활인구수':'여자45세부터49세생활인구수',
       '여자45세부터49세생활인구수':'여자50세부터54세생활인구수', '여자50세부터54세생활인구수':'여자55세부터59세생활인구수', '여자55세부터59세생활인구수':'여자60세부터64세생활인구수',
       '여자60세부터64세생활인구수':'여자65세부터69세생활인구수', '여자65세부터69세생활인구수':'여자70세이상생활인구수','여자70세이상생활인구수':'null'},inplace =True)

# %%
df_total.drop(columns = ['null'])
# Out:
#         행정동코드    총생활인구수       남자0세부터9세생활인구수 남자10세부터14세생활인구수  \
# 0          00  11110560  18298.601699999999        542.7872
# 1          00  11140625          13906.9668        373.7146
# 2          00  11710631  32190.094300000001       1329.3009
# 3          00  11680630  30591.927500000002        702.7857
# 4          00  11440720          22091.3105        520.8461
# ...       ...       ...                 ...             ...
# 3714235    23  11110560  18530.063300000002        539.9718
# 3714236    23  11110670  6238.8665000000001         53.9233
# 3714237    23  11740690  5271.8468999999996        229.7714
# 3714238    23  11560720          25025.5448        311.2179
# 3714239    23  11680580  21396.355500000001        762.1061
#
#             남자15세부터19세생활인구수     남자20세부터24세생활인구수     남자25세부터29세생활인구수  \
# 0                  392.6157  506.81360000000001  595.33969999999999
# 1        206.45060000000001            223.3708  405.73820000000001
# ...

# %%
### 분석 대상 
## 평일평균 유동인구수 , 주말평균 유동인구수 , 주별 평균

# %%
# seongsu 지역만 filtering 
df_total = df_total[(df_total['행정동코드'] == 11200650) | (data['행정동코드'] == 11200660) | (data['행정동코드'] == 11200670) | (data['행정동코드'] == 11200690)]

# %%
df_total.head()

# %%
# 지수코드 변환 
pd.options.display.float_format = '{:.2f}'.format

# %%
#성수 전체 유동인구수
seongsu = df_total.groupby('기준일ID')['총생활인구수'].sum()

# %%
total_of_day = pd.Dataframe(seongsu)

# %%
total_of_day.index

# %%
week = []
ju = []

for idx, row in total_of_day.iterrows():
    year = str(idx)[:4]
    month = str(idx)[4:6]
    day = str(idx)[6:]
    weekday = date(int(year), int(month), int(day)).weekday()
    
    if weekday > 4 :
        week.append('주말')
        
    else:
        week.append('평일')
    ju.append(datetime(int(year), int(month), int(day)).isocalender()[1])
    print('행 인덱스 : ',idx)
    print(row['총생활인구수'], '\n')

# %%
print(week, ju)

# %%
total_of_day['요일'] = week
total_of_day['주차'] = ju

# %%
### 통계량 확인 

mean_of_day = total_of_day.groupby('요일')['총생활인구수'].mean()
median_of_day = total_of_day.groupby('요일')['총생활인구수'].median()
mean_of_week =

# %%
a = pd.DataFrame(mean_of_day)
b = pd.DataFrame(median_of_day)

# %%
population_of_day = pd.concat([a,b],axis =1 , join = 'inner')
print(population_of_day)

# %%
population_of_day.columns = ['유동인구수(평균)','유동인구수(중앙값)']
population_of_day = population_of_day.astype('int')

# %%
mean_of_week = total_of_day.groupby('주차')['총생활인구수'].mean()
median_of_week = total_of_day.groupby('주차')['총생활인구수'].median()

# %%
c = pd.DataFrame(mean_of_week)
d = pd.DataFrame(median_of_week)

# %%
population_of_week = pd.concat([c,d],axis =1 , join = 'inner')
print(population_of_week)

# %%
population_of_week.columns = ['유동인구수(평균)','유동인구수(중앙값)']
population_of_we = population_of_day.astype('int')
