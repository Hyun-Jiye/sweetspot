# %%
import pandas as pd

# %%
df = pd.read_csv('data/tenant_menu.csv', encoding='cp949')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94404 entries, 0 to 94403
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   seq         94404 non-null  int64
#  1   tenant_seq  94404 non-null  int64
#  2   title       94404 non-null  object
#  3   price       92756 non-null  float64
#  4   content     51742 non-null  object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.6+ MB

# %%
df.shape
# Out:
# (94404, 5)

# %%
df['price'].isna().sum()
# Out:
# 1648

# %%
df['price'].fillna(0, inplace=True)

# %%
df['price'].isna().sum()
# Out:
# 0

# %%
for price in df['price']:
    print(str(int(price)))
# Out:
# 4200
# 4200
# 3600
# 3900
# 3800
# 3900
# 3800
# 13900
# 6000
# 4000
# 18900
# 9500
# 4300
# 26000
# 7700
# 4300
# 32000
# 8800
# 4300
# 18000
# 5500
# 3900
# 22000
# 5500
# 3600
# 27000
# 4500
# 32000
# 36000
# 7800
# 32000
# 8400
# 5500
# 7800
# 4500
# 5500
# 9300
# 20000
# 29000
# 14500
# 14500
# 19500
# 20500
# 21500
# 22500
# 24500
# 31500
# 26500
# 11000
# 11000
# 11000
# 16900
# 23500
# 42000
# 40000
# 40000
# 13000
# 11900
# 11900
# 7900
# 11900
# 14900
# 5900
# 8900
# 11900
# 12900
# 15900
# 8500
# 29900
# 9000
# 34900
# 9000
# 36900
# 2700
# 4000
# 7500
# 8000
# 5000
# 6000
# 6500
# 6500
# 7000
# 14000
# 14000
# 14000
# 12000
# 14000
# 49000
# 28000
# 32000
# 18000
# 32000
# 54000
# 33000
# 28000
# 26000
# 28000
# 26000
# 33000
# 22000
# 26000
# 24000
# 26000
# 30000
# 19000
# 26000
# 18000
# 24000
# 26000
# 24000
# 28000
# 28000
# 36000
# 24000
# 24000
# 18000
# 9000
# 30000
# 50000
# 50000
# 70000
# 35000
# 35000
# 48000
# 39000
# 29000
# 34000
# 34000
# 29000
# 12000
# ...
