# %%
import pandas as pd 
import numpy as np

# %%
df_seoul = pd.read_csv('../서울시 일반음식점 인허가 정보.csv', encoding = 'utf-8')
# Out:
# /var/folders/06/tbmdvc413xncjxzs56w_xd100000gn/T/ipykernel_1353/3232217995.py:1: DtypeWarning: Columns (2,8,13,14,25,27,28,29,30,36,39,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_seoul = pd.read_csv('../서울시 일반음식점 인허가 정보.csv', encoding = 'utf-8')

# %%
df_seoul.columns
# Out:
# Index(['개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자', '영업상태코드', '영업상태명', '상세영업상태코드',
#        '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '전화번호', '소재지면적',
#        '소재지우편번호', '지번주소', '도로명주소', '도로명우편번호', '사업장명', '최종수정일자', '데이터갱신구분',
#        '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '위생업태명', '남성종사자수', '여성종사자수',
#        '영업장주변구분명', '등급구분명', '급수시설구분명', '총인원', '본사종업원수', '공장사무직종업원수',
#        '공장판매직종업원수', '공장생산직종업원수', '건물소유구분명', '보증액', '월세액', '다중이용업소여부', '시설총규모',
#        '전통업소지정번호', '전통업소주된음식', '홈페이지'],
#       dtype='object')

# %%
df1 = df_seoul[['사업장명']]

# %%
df1_list = df1.values.tolist()

# %%
df1.value_counts
# Out:
# <bound method DataFrame.value_counts of                  사업장명
# 0            매취랑 동대문점
# 1             청춘부추소곱창
# 2                 치카바
# 3                 오고보
# 4         또봉이통닭 가락본동점
# ...               ...
# 497596  메가엠지씨커피 신용산역점
# 497597          황제꼼장어
# 497598           면가요시
# 497599       대식대 소룡포자
# 497600          희래등반점
#
# [497601 rows x 1 columns]>

# %%
df2 = pd.read_csv('../data_pb.csv'
                  ,encoding = 'utf-8')

# %%
df2 = df2[['매장명']]

# %%
df_sec = df2.values.tolist()
df_sec[0]
# Out:
# ['(주)용마을 용우동']

# %%
df1_list 
# df_sec
# Out:
# [['매취랑 동대문점'],
#  ['청춘부추소곱창'],
#  ['치카바'],
#  ['오고보'],
#  ['또봉이통닭 가락본동점'],
#  ['파이어벨'],
#  ['양이야기'],
#  ['대치동그집1981'],
#  ['슈바'],
#  ['왔따쪽갈비'],
#  ['서촌 곳간'],
#  ['복림문'],
#  ['카페 라'],
#  ['역전우동0410 숙대입구점'],
#  ['끼(KKI)'],
#  ['마라공방'],
#  ['첨복'],
#  ['랩보이(wrap boy)'],
#  ['귀한족발 우장산점'],
#  ['은가비'],
#  ['동래정 화곡점'],
#  ['아가젤라또(성수)'],
#  ['위트 에스프레소바'],
#  ['고기반햄반 김치찌개&김치찜'],
#  ['향래원마라탕'],
#  ['단골손님 상봉점'],
#  ['홈푸드 스토리'],
#  ['수지상회&슈퍼통닭 상봉점'],
#  ['유유(uu)'],
#  ['별관'],
#  ['한성돼'],
#  ['도쿄술집(성신여대점)'],
#  ['현방오백소갈비살'],
#  ['찐하오 마라탕'],
#  ['더피자 은평점'],
#  ['소담유부'],
#  ['토쿠이'],
#  ['도시피자 상암점'],
#  ['몽란'],
#  ['옥자 성수'],
#  ['미자 서울'],
#  ['전주밥차'],
#  ['하봉참치스시'],
#  ['충당'],
#  ['봉구스 밥버거'],
#  ['모루야'],
#  ['아쿠아리어스 AQuarius'],
#  ['브리즈커피'],
#  ['유브유부 먼키구디점'],
#  ['불타는 포차'],
#  ['브라운베이글 구로점'],
#  ['힘내 커피'],
#  ['김밥오리진(Origin)'],
#  ['마라도둑'],
#  ['장위 DON 참숯구이'],
#  ['네오'],
#  ['두레유'],
#  ['한라맥주 오목교점'],
#  ['스타주점'],
#  ['십리향'],
#  ['카츠오도 낙성대점'],
#  ['구룡관 혜화본점'],
#  ['두번먹는 명인김치찜'],
#  ['삼호령 김치찜'],
# ...

# %%
df1_list

df1_list.__contains__(['향래원마라탕'])
# Out:
# True

# %%
for i in df1_list:
    print(i)
    break
# Out:
# ['매취랑 동대문점']

# %%
no_false = []
for i in df_sec: 
    bool_a = df1_list.__contains__(i)
    if bool_a is True : 
        print('일치합니다', i)
        no_false.append(i)
        
    else : 
        print('불일치합니다') 
print(f' 총 5000개 이상의 가져오지 못한 면적데이터 중 상호명과 주소가 일치하는 데이터는 {len(no_false)}개 있는 것으로 확인')
# Out:
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 일치합니다 ['33떡볶이 고덕그라시움점']
# 일치합니다 ['33떡볶이 고덕래미안힐스점']
# 불일치합니다
# 일치합니다 ['33떡볶이 송파헬리오점']
# 일치합니다 ['33떡볶이 위례중앙점']
# 일치합니다 ['33떡볶이 잠실엘스점']
# 일치합니다 ['33떡볶이 파크하비오점']
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 일치합니다 ['37.5 서래마을점']
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 일치합니다 ['60계치킨 서울이수점']
# 일치합니다 ['60계치킨 서울장위뉴타운점']
# 불일치합니다
# 불일치합니다
# 일치합니다 ['60계치킨 천호역점']
# 일치합니다 ['798화로 홍대본점']
# 불일치합니다
# 일치합니다 ['7번가피자 공릉점']
# 일치합니다 ['7번가피자 내곡점']
# 불일치합니다
# 일치합니다 ['7번가피자 성내점']
# 일치합니다 ['7번가피자 신촌마포점']
# 불일치합니다
# 불일치합니다
# 일치합니다 ['7번가피자 화곡신월점']
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 일치합니다 ['JVL부대찌개 가산디폴리스점']
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 일치합니다 ['JVL부대찌개 현대시티몰 가든파이브점']
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# ...

# %% [markdown]
# 상호명과 인허가명(사업장명)이 일치하지 않아서 가져오지 못하는 문제가 맞는지?
# 웹크롤링에서 전체데이터 수집 후 비교하는 로직? -> 비교시 상호명과 사업장명의 띄어쓰기 등을 제거하고 순수한 word로만 비교하는지
# api data로 받아오는건 무관

# %% [markdown]
# ? 물어볼 것 ?
#     - 상호명으로 대조를 해서 가져와도 불일치건이 약 3500+a 개 이상 된다. (그러나 , 일반음식점 한정)
#     - 어떤 방식으로 가져올지
#         - 서울시말고 지방 인허가 데이터 페이지에 가면 전국에 있는 데이터(서울시로 1차 필터링) 를 모두 취합이 가능함.
#     - 휴게음식 + 일반음식 + 기타 인허가 데이터에서 더 많은 데이터가 일치할 수 있음.
#     - 크롤러 구동방식을 볼 수 있으면 더 문제파악이 쉬울 것 같다. (어려워도 있는것과 없는것이 다를 듯..)

# %% [markdown]
# month 월별 기준이 있으면, 시계열 파악이 가능
# - month 별 매출, 평점, 등이 있고, 매월 created_at 이 생성됨
# - 매출 테이블도 따로 관리되고 있음.
# - 오픈업 추정치 제공 8월 자 매출 데이터면 6월 매출로 제공
#
#
# * tenant -> 최초 한번
# * tenant_crawling 은 계속 누적되는 테이블

# %%
df = pd.read_csv('./인허가 데이터 합/서울시 제과점영업 인허가 정보.csv',encoding = 'cp949')

# %%
df.head()
# Out:
#    개방자치단체코드                    관리번호       인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0   3220000  3220000-121-2023-00040  2023-04-04      NaN       1  영업/정상
# 1   3240000  3240000-121-2017-00026  2017-08-14      NaN       1  영업/정상
# 2   3230000  3230000-121-2017-00031  2017-08-14      NaN       3     폐업
# 3   3220000  3220000-121-2023-00041  2023-04-04      NaN       3     폐업
# 4   3180000  3180000-121-2023-00032  2023-06-19      NaN       1  영업/정상
#
#    상세영업상태코드 상세영업상태명        폐업일자  휴업시작일자  ...  공장판매직종업원수  공장생산직종업원수 건물소유구분명  \
# 0         1      영업         NaN     NaN  ...        NaN        NaN     NaN
# 1         1      영업         NaN     NaN  ...        NaN        NaN     NaN
# 2         2      폐업  2023-04-04     NaN  ...        NaN        NaN     NaN
# 3         2      폐업  2023-04-30     NaN  ...        NaN        NaN     NaN
# 4         1      영업         NaN     NaN  ...        NaN        NaN     NaN
#
#   보증액 월세액 다중이용업소여부 시설총규모  전통업소지정번호 전통업소주된음식 홈페이지
# ...

# %% [markdown]
# columns 명이 달라서 생기는 문제 -> 확인해보아야 한다.

# %%
bake_df = pd.read_csv('./서울시 제과점영업 인허가 정보.csv', encoding = 'cp949') 
bake_df = bake_df[['지번주소','사업장명']]

# %%
bake_df.rename(columns={'지번주소' : '소재지전체주소'}, inplace=True)

# %%
bake_df
# Out:
#                                   소재지전체주소                              사업장명
# 0              서울특별시 강남구 압구정동 494 갤러리아백화점                      빵준서 갤러리아 명품관
# 1                     서울특별시 강동구 성내동 560-1                MIN Bakery(민 베이커리)
# 2                    서울특별시 송파구 풍납동 155-20                MIN Bakery(민 베이커리)
# 3              서울특별시 강남구 압구정동 494 갤러리아백화점                      베시 더 스콘(한시적)
# 4             서울특별시 영등포구 당산동3가 512 당산M팰리스            아워슈가클럽(our sugar club)
# ...                                   ...                               ...
# 13935          서울특별시 강남구 압구정동 494 갤러리아백화점                꼬모윤(comoyoon)(한시적)
# 13936                서울특별시 서초구 우면동 64 건빌딩                       파리바게뜨 서초우면점
# 13937             서울특별시 강남구 역삼동 755 한솔필리아  프로틴 퀸_u(역삼)/ Protein Queen_u(역삼)
# 13938  서울특별시 서초구 반포동 19-3 신세계백화점 강남점 지하1층                               피르마
# 13939      서울특별시 영등포구 여의도동 60 63한화생명빌딩 7층                          라이프플러스카페
#
# [13940 rows x 2 columns]

# %%
rest_df = pd.read_csv('./fulldata_07_24_05_P_휴게음식점.csv',encoding = 'cp949')
rest_df = rest_df[['소재지전체주소','사업장명']]
# Out:
# /var/folders/06/tbmdvc413xncjxzs56w_xd100000gn/T/ipykernel_1353/2132707028.py:1: DtypeWarning: Columns (11,39,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   rest_df = pd.read_csv('./fulldata_07_24_05_P_휴게음식점.csv',encoding = 'cp949')

# %%
norm_df = pd.read_csv('./fulldata_07_24_04_P_일반음식점.csv', encoding = 'cp949')
norm_df = norm_df[['소재지전체주소','사업장명']]
# Out:
# /var/folders/06/tbmdvc413xncjxzs56w_xd100000gn/T/ipykernel_1353/205009454.py:1: DtypeWarning: Columns (11,27,39,41,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   norm_df = pd.read_csv('./fulldata_07_24_04_P_일반음식점.csv', encoding = 'cp949')

# %% [markdown]
# #### 확인결과
#  - 제과점은 소재지전체주소가 지번주소로 되어있음
#  - 그래서 늘어나는 rows가 없었던 것

# %% [markdown]
# ------

# %%
df_all_fnb = pd.concat([bake_df,rest_df,norm_df])

# %%
df_all_fnb.head()
# Out:
#                        소재지전체주소                    사업장명
# 0   서울특별시 강남구 압구정동 494 갤러리아백화점            빵준서 갤러리아 명품관
# 1          서울특별시 강동구 성내동 560-1      MIN Bakery(민 베이커리)
# 2         서울특별시 송파구 풍납동 155-20      MIN Bakery(민 베이커리)
# 3   서울특별시 강남구 압구정동 494 갤러리아백화점            베시 더 스콘(한시적)
# 4  서울특별시 영등포구 당산동3가 512 당산M팰리스  아워슈가클럽(our sugar club)

# %%
df_all_fnb = df_all_fnb[df_all_fnb['소재지전체주소'].str.contains('서울특별시' ,na=False)] #소재지 서울특별시만 뽑아냄.

# %%
df_all_fnb[['소재지전체주소']]
# Out:
#                              소재지전체주소
# 0         서울특별시 강남구 압구정동 494 갤러리아백화점
# 1                서울특별시 강동구 성내동 560-1
# 2               서울특별시 송파구 풍납동 155-20
# 3         서울특별시 강남구 압구정동 494 갤러리아백화점
# 4        서울특별시 영등포구 당산동3가 512 당산M팰리스
# ...                              ...
# 2073906  서울특별시 은평구 진관동 72 드림스퀘어 105호
# 2073907         서울특별시 은평구 진관동 296-12
# 2073908           서울특별시 은평구 대조동 68-2
# 2074038          서울특별시 광진구 광장동 322-6
# 2075326       서울특별시 강서구 화곡동 827-2 1층
#
# [638032 rows x 1 columns]

# %%
df_all_fnb['소재지전체주소'].count()
# Out:
# 638032

# %%
df_all_fnb_name = df_all_fnb[['사업장명']]

# %%
df_all_fnb_name
# Out:
#                            사업장명
# 0                  빵준서 갤러리아 명품관
# 1            MIN Bakery(민 베이커리)
# 2            MIN Bakery(민 베이커리)
# 3                  베시 더 스콘(한시적)
# 4        아워슈가클럽(our sugar club)
# ...                         ...
# 2073906              미소야(구파발역점)
# 2073907               북한산큰숲,제빵소
# 2073908                     베엔타
# 2074038                 37.5광진점
# 2075326             꾸어가게생선구이화곡점
#
# [638032 rows x 1 columns]

# %%
df_all_fnb_name= df_all_fnb_name.values.tolist()

# %%
print(len(df_sec))
# Out:
# 5054

# %%
no_false = []
for i in df_sec: 
    bool_a = df_all_fnb_name.__contains__(i)
    if bool_a is True : 
        print('일치합니다', i)
        no_false.append(i)
        
    else : 
        print('불일치합니다') 
print(f' 총 5000개 이상의 가져오지 못한 면적데이터 중 상호명이 일치하는 데이터는 {len(no_false)}개 있는 것으로 확인')
# Out:
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 일치합니다 ['33떡볶이 고덕그라시움점']
# 일치합니다 ['33떡볶이 고덕래미안힐스점']
# 불일치합니다
# 일치합니다 ['33떡볶이 송파헬리오점']
# 일치합니다 ['33떡볶이 위례중앙점']
# 일치합니다 ['33떡볶이 잠실엘스점']
# 일치합니다 ['33떡볶이 파크하비오점']
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 일치합니다 ['37.5 서래마을점']
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 일치합니다 ['60계치킨 서울이수점']
# 일치합니다 ['60계치킨 서울장위뉴타운점']
# 불일치합니다
# 불일치합니다
# 일치합니다 ['60계치킨 천호역점']
# 일치합니다 ['798화로 홍대본점']
# 불일치합니다
# 일치합니다 ['7번가피자 공릉점']
# 일치합니다 ['7번가피자 내곡점']
# 불일치합니다
# 일치합니다 ['7번가피자 성내점']
# 일치합니다 ['7번가피자 신촌마포점']
# 불일치합니다
# 불일치합니다
# 일치합니다 ['7번가피자 화곡신월점']
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 일치합니다 ['JVL부대찌개 가산디폴리스점']
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 일치합니다 ['JVL부대찌개 현대시티몰 가든파이브점']
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# 불일치합니다
# ...
