# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 데이터 불러오기

# %%
data1 = pd.read_excel('data/스테이션/스테이션 월계점 판매 데이터 (24.01~04)/스테이션 월계점 판매 데이터_24.01.xlsx')
data2 = pd.read_excel('data/스테이션/스테이션 월계점 판매 데이터 (24.01~04)/스테이션 월계점 판매 데이터_24.02.xlsx')
data3 = pd.read_excel('data/스테이션/스테이션 월계점 판매 데이터 (24.01~04)/스테이션 월계점 판매 데이터_24.03.xlsx')
data4 = pd.read_excel('data/스테이션/스테이션 월계점 판매 데이터 (24.01~04)/스테이션 월계점 판매 데이터_24.04.xlsx')

# %% [markdown]
# ### 데이터 통합

# %%
d1 = pd.concat([data1, data2], axis=0)
d2 = pd.concat([d1, data3], axis=0)
df = pd.concat([d2, data4], axis=0)

# %%
df
# Out:
#          그룹: 판매일자 그룹: 브랜드명      #       매장      매장명        판매일자     전표번호  \
# 0    ▷ 2024-01-01      NaN    NaN   전체 88건      NaN         NaN      NaN
# 1             NaN     ▷ 마니    NaN   전체 22건      NaN         NaN      NaN
# 2             NaN      NaN    1.0     M012  이마트_월계점  2024-01-01  11078.0
# 3             NaN      NaN    2.0     M012  이마트_월계점  2024-01-01  11020.0
# 4             NaN      NaN    3.0     M012  이마트_월계점  2024-01-01  11033.0
# ..            ...      ...    ...      ...      ...         ...      ...
# 909           NaN      NaN  722.0     M012  이마트_월계점  2024-04-25  11009.0
# 910           NaN      NaN  723.0     M012  이마트_월계점  2024-04-25  11003.0
# 911           NaN      NaN  724.0     M012  이마트_월계점  2024-04-25  11011.0
# 912           NaN      NaN  725.0     M012  이마트_월계점  2024-04-25  11006.0
# 913          [전체]      NaN    NaN  전체 725건      NaN         NaN      NaN
#
#      브랜드명      카테고리     실판매금액  수량합계            본사바코드  참고사항
# 0     NaN       NaN   1801800   102              NaN   NaN
# 1     NaN       NaN    614600    21              NaN   NaN
# 2      마니      여성의류     69000     1  B235KA99400000F   NaN
# 3      마니      여성의류    -19900    -1  B235KA99400000F   NaN
# 4      마니      여성의류     27000     1  B235KA99400000F   NaN
# ..    ...       ...       ...   ...              ...   ...
# 909  클레이즈  모자 및 스카프     10000     1  B235KA06600000F   NaN
# 910  클레이즈  모자 및 스카프     35000     1  B235KA06600000F   NaN
# 911  클레이즈  모자 및 스카프     60000     2  B235KA06600000F   NaN
# 912  클레이즈  모자 및 스카프     35000     1  B235KA06600000F   NaN
# 913   NaN       NaN  14415630   843              NaN   NaN
#
# [5948 rows x 13 columns]

# %% [markdown]
# ### 불필요한 컬럼 제거

# %%
df = df.drop(df.columns[:3], axis=1)
df
# Out:
#           매장      매장명        판매일자     전표번호  브랜드명      카테고리     실판매금액  수량합계  \
# 0     전체 88건      NaN         NaN      NaN   NaN       NaN   1801800   102
# 1     전체 22건      NaN         NaN      NaN   NaN       NaN    614600    21
# 2       M012  이마트_월계점  2024-01-01  11078.0    마니      여성의류     69000     1
# 3       M012  이마트_월계점  2024-01-01  11020.0    마니      여성의류    -19900    -1
# 4       M012  이마트_월계점  2024-01-01  11033.0    마니      여성의류     27000     1
# ..       ...      ...         ...      ...   ...       ...       ...   ...
# 909     M012  이마트_월계점  2024-04-25  11009.0  클레이즈  모자 및 스카프     10000     1
# 910     M012  이마트_월계점  2024-04-25  11003.0  클레이즈  모자 및 스카프     35000     1
# 908  B235KA06600000F
# 909  B235KA06600000F
# 910  B235KA06600000F
# 911  B235KA06600000F
# 912  B235KA06600000F
#
# [5177 rows x 9 columns]

# %% [markdown]
# ### 데이터 처리

# %% [markdown]
# 1. 기존에 있는 '실판매금액'이라는 컬럼명을 '판매금액'으로 변경
# 2. 기존에 있는 '수량합계'라는 컬럼명을 '판매수량'으로 변경
# 3. 8번째 열(인덱스: 7)에 '환불금액'이라는 새 컬럼 생성 (데이터 값은 nan으로)
# 4. 10번째 열(인덱스: 9)에 '환불수량'이라는 새 컬럼 생성 (데이터 값은 nan으로)
# 5. '판매금액'이라는 컬럼에서 음수(0 미만)인 데이터는 '환불금액'이라는 컬럼에 해당 '판매금액' 값의 절댓값으로 채운 뒤, '판매금액' 값은 nan으로 변경
# 6. '판매수량'이라는 컬럼에서 음수(0 미만)인 데이터는 '환불수량'이라는 컬럼에 해당 '판매수량' 값의 절댓값으로 채운 뒤, '판매수량' 값은 nan으로 변경

# %%
# 컬럼명 변경
df.rename(columns={'실판매금액': '판매금액'}, inplace=True)
df.rename(columns={'수량합계': '판매수량'}, inplace=True)

# 새 컬럼 생성
df.insert(7, '환불금액', np.nan)
df.insert(9, '환불수량', np.nan)

# 환불 데이터 처리 - 새로운 열에 삽입 후 기존 판매 데이터 삭제
df.loc[df['판매금액'] < 0, '환불금액'] = df.loc[df['판매금액'] < 0, '판매금액'].abs()
df.loc[df['판매금액'] < 0, '판매금액'] = np.nan

df.loc[df['판매수량'] < 0, '환불수량'] = df.loc[df['판매수량'] < 0, '판매수량'].abs()
df.loc[df['판매수량'] < 0, '판매수량'] = np.nan

df
# Out:
# C:\Users\Puser\AppData\Local\Temp\ipykernel_12444\604161916.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'실판매금액': '판매금액'}, inplace=True)
# C:\Users\Puser\AppData\Local\Temp\ipykernel_12444\604161916.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'수량합계': '판매수량'}, inplace=True)
#        매장      매장명        판매일자     전표번호  브랜드명      카테고리     판매금액     환불금액  \
# 2    M012  이마트_월계점  2024-01-01  11078.0    마니      여성의류  69000.0      NaN
# 3    M012  이마트_월계점  2024-01-01  11020.0    마니      여성의류      NaN  19900.0
# 4    M012  이마트_월계점  2024-01-01  11033.0    마니      여성의류  27000.0      NaN
# 5    M012  이마트_월계점  2024-01-01  11058.0    마니      여성의류      NaN  19900.0
# 6    M012  이마트_월계점  2024-01-01  11034.0    마니      여성의류  27000.0      NaN
# ..    ...      ...         ...      ...   ...       ...      ...      ...
# 908  M012  이마트_월계점  2024-04-25  11017.0  클레이즈  모자 및 스카프  10000.0      NaN
# 909  M012  이마트_월계점  2024-04-25  11009.0  클레이즈  모자 및 스카프  10000.0      NaN
# 910  M012  이마트_월계점  2024-04-25  11003.0  클레이즈  모자 및 스카프  35000.0      NaN
# 911  M012  이마트_월계점  2024-04-25  11011.0  클레이즈  모자 및 스카프  60000.0      NaN
# 912  M012  이마트_월계점  2024-04-25  11006.0  클레이즈  모자 및 스카프  35000.0      NaN
#
#      판매수량  환불수량            본사바코드
# 2     1.0   NaN  B235KA99400000F
# 3     NaN   1.0  B235KA99400000F
# 4     1.0   NaN  B235KA99400000F
# 5     NaN   1.0  B235KA99400000F
# 6     1.0   NaN  B235KA99400000F
# ..    ...   ...              ...
# 908   1.0   NaN  B235KA06600000F
# 909   1.0   NaN  B235KA06600000F
# 910   1.0   NaN  B235KA06600000F
# 911   2.0   NaN  B235KA06600000F
# 912   1.0   NaN  B235KA06600000F
#
# [5177 rows x 11 columns]

# %% [markdown]
# ### 데이터 타입 변경

# %%
df.dtypes
# Out:
# 매장        object
# 매장명       object
# 판매일자      object
# 전표번호     float64
# 브랜드명      object
# 카테고리      object
# 판매금액     float64
# 환불금액     float64
# 판매수량     float64
# 환불수량     float64
# 본사바코드     object
# dtype: object

# %%
df['전표번호'] = df['전표번호'].astype('object')
df['판매금액'] = df['판매금액'].astype('Int64')
df['환불금액'] = df['환불금액'].astype('Int64')
df['판매수량'] = df['판매수량'].astype('Int64')
df['환불수량'] = df['환불수량'].astype('Int64')

df.dtypes
# Out:
# C:\Users\Puser\AppData\Local\Temp\ipykernel_12444\1017662846.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['전표번호'] = df['전표번호'].astype('object')
# C:\Users\Puser\AppData\Local\Temp\ipykernel_12444\1017662846.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['판매금액'] = df['판매금액'].astype('Int64')
# C:\Users\Puser\AppData\Local\Temp\ipykernel_12444\1017662846.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['환불금액'] = df['환불금액'].astype('Int64')
# C:\Users\Puser\AppData\Local\Temp\ipykernel_12444\1017662846.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['판매수량'] = df['판매수량'].astype('Int64')
# C:\Users\Puser\AppData\Local\Temp\ipykernel_12444\1017662846.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['환불수량'] = df['환불수량'].astype('Int64')
# 매장       object
# 매장명      object
# 판매일자     object
# 전표번호     object
# 브랜드명     object
# 카테고리     object
# 판매금액      Int64
# 환불금액      Int64
# 판매수량      Int64
# 환불수량      Int64
# 본사바코드    object
# dtype: object

# %%
df
# Out:
#        매장      매장명        판매일자     전표번호  브랜드명      카테고리   판매금액   환불금액  판매수량  \
# 2    M012  이마트_월계점  2024-01-01  11078.0    마니      여성의류  69000   <NA>     1
# 3    M012  이마트_월계점  2024-01-01  11020.0    마니      여성의류   <NA>  19900  <NA>
# 4    M012  이마트_월계점  2024-01-01  11033.0    마니      여성의류  27000   <NA>     1
# 5    M012  이마트_월계점  2024-01-01  11058.0    마니      여성의류   <NA>  19900  <NA>
# 6    M012  이마트_월계점  2024-01-01  11034.0    마니      여성의류  27000   <NA>     1
# ..    ...      ...         ...      ...   ...       ...    ...    ...   ...
# 908  M012  이마트_월계점  2024-04-25  11017.0  클레이즈  모자 및 스카프  10000   <NA>     1
# 909  M012  이마트_월계점  2024-04-25  11009.0  클레이즈  모자 및 스카프  10000   <NA>     1
# 910  M012  이마트_월계점  2024-04-25  11003.0  클레이즈  모자 및 스카프  35000   <NA>     1
# 911  M012  이마트_월계점  2024-04-25  11011.0  클레이즈  모자 및 스카프  60000   <NA>     2
# 912  M012  이마트_월계점  2024-04-25  11006.0  클레이즈  모자 및 스카프  35000   <NA>     1
#
#      환불수량            본사바코드
# 2    <NA>  B235KA99400000F
# 3       1  B235KA99400000F
# 4    <NA>  B235KA99400000F
# 5       1  B235KA99400000F
# 6    <NA>  B235KA99400000F
# ..    ...              ...
# 908  <NA>  B235KA06600000F
# 909  <NA>  B235KA06600000F
# 910  <NA>  B235KA06600000F
# 911  <NA>  B235KA06600000F
# 912  <NA>  B235KA06600000F
#
# [5177 rows x 11 columns]

# %% [markdown]
# ### 데이터 저장

# %%
df.to_excel('스테이션_월계점.xlsx', index=False)
