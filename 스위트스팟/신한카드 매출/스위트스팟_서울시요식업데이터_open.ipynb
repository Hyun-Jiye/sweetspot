# %%
import pandas as pd

# %%
data = pd.read_csv('./신한카드_최종.txt', sep = "|", encoding='cp949')

# %%
data.head()
# Out:
#     TA_YM MCT_RY_NM       MCTNM BRD_NM      ARED BZNCD     LALXCVL    LALYCVL  \
# 0  202304        양식          큐리    NaN  20230316   이태원  126.989622  37.533448
# 1  202307        한식         온달네    NaN  20130329   NaN  127.075786  37.630286
# 2  202312        한식     연희동 만석집    NaN  20190812   연희동  126.929971  37.566636
# 3  202312     커피전문점     숲(Soop)    NaN  20211027   NaN  127.001454  37.617634
# 4  202312        한식  무침표홍어무침&보쌈    NaN  20230823  신월4동  126.843492  37.516763
#
#    EST_AMT_TOT  EST_CNT_TOT  ...  소득5천만이하  소득7천만이하  소득1억이하  소득1억초과  생애단계_싱글  \
# 0     23549507          450  ...   37.818    8.495   2.765   5.506   83.458
# 1     67329528          978  ...   40.950   20.372  11.218  11.734   40.915
# 2     19803263          136  ...   12.267   10.279  16.920  53.722   18.824
# 3     13708933         1211  ...   35.152   24.502  15.805   9.296   34.800
# 4      7486687          249  ...   44.074   13.833  27.153   9.014   30.869
#
# ...

# %%
data['TA_YM']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1386422 entries, 0 to 1386421
# Data columns (total 37 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   TA_YM            1386422 non-null  int64
#  1   MCT_RY_NM        1386422 non-null  object
#  2   MCTNM            1386422 non-null  object
#  3   BRD_NM           354076 non-null   object
#  4   ARED             1386422 non-null  int64
#  5   BZNCD            1117092 non-null  object
#  6   LALXCVL          1386422 non-null  float64
#  7   LALYCVL          1386422 non-null  float64
#  8   EST_AMT_TOT      1386422 non-null  int64
#  9   EST_CNT_TOT      1386422 non-null  int64
#  10  WKND_RT          1386422 non-null  float64
#  11  시간_0813          1386422 non-null  float64
#  12  시간_1417          1386422 non-null  float64
#  13  시간_1821          1386422 non-null  float64
#  14  시간_2207          1386422 non-null  float64
# ...
